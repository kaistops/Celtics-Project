# %%
# import pandas as pd 
# import numpy as np

# from nba_api.stats.static import teams

# nba_teams = teams.get_teams()
# # Select the dictionary for the Celtics, which contains their team ID
# celtics = [team for team in nba_teams if team['abbreviation'] == 'BOS'][0]
# celtics_id = celtics['id']

# from nba_api.stats.endpoints import leaguegamefinder
# gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=celtics_id)
# celtics_games = gamefinder.get_data_frames()[0]

# gamefinder = leaguegamefinder.LeagueGameFinder(vs_team_id_nullable=celtics_id)
# opponent_games = gamefinder.get_data_frames()[0]

# all_games = pd.concat([celtics_games, opponent_games], axis=0)

# all_games = all_games.sort_values(by='GAME_DATE', ascending=False)

# all_games = all_games[all_games['SEASON_ID'].isin(['22022', '12022', '42021', '22021', '12021', '42020', '52020',
#        '22020', '12020', '42019', '22019', '12019', '42018', '22018', '12018', '42017', '22017', '12017'])]

display(all_games)
all_games.to_csv('all_games.csv')



# game_ids = all_games['GAME_ID'].unique()

# from nba_api.stats.endpoints import boxscoretraditionalv2
# seasons = ['22022', '12022', '42021', '22021', '12021', '42020', '52020', '22020', '12020', '42019', '22019', 
#            '12019', '42018', '22018', '12018', '42017', '22017', '12017']

# for season in seasons:

# game_ids_12017  = all_games.loc('SEASON_ID' == '12017')['GAME_ID'].unique()
# display(game_ids_2017)
# # box_scores = pd.DataFrame()
# # for game_id in game_ids:
# #        box_score = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id)
# #        box_score = box_score.get_data_frames()[0]
# #        box_scores = pd.concat([box_scores, box_score])
# # display(box_scores)
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION            TEAM_NAME     GAME_ID  \
# 0       22022  1610612738               BOS       Boston Celtics  0022200935
# 0       22022  1610612739               CLE  Cleveland Cavaliers  0022200935
# 1       22022  1610612738               BOS       Boston Celtics  0022200921
# 1       22022  1610612752               NYK      New York Knicks  0022200921
# 2       22022  1610612738               BOS       Boston Celtics  0022200908
# ..        ...         ...               ...                  ...         ...
# 579     22017  1610612762               UTA            Utah Jazz  1621700006
# 581     22017  1610612738               BOS       Boston Celtics  1621700003
# 580     22017  1610612759               SAS    San Antonio Spurs  1621700003
# 582     22017  1610612738               BOS       Boston Celtics  1621700001
# 581     22017  1610612755               PHI   Philadelphia 76ers  1621700001
#
# ...

# %%
# from nba_api.stats.endpoints import teamgamelog
# help(teamgamelog)
# gamelog= teamgamelog.TeamGameLog(celtics_id)
# gamelog = gamelog.get_data_frames()[0]
# display(gamelog.columns)
# display(gamelog)


# from nba_api.stats.endpoints import boxscoreplayertrackv2
# boxscoreplayertrackv2 = boxscoreplayertrackv2.BoxScorePlayerTrackV2(game_id='0022200935')
# boxscoreplayertrackv2 = boxscoreplayertrackv2.get_data_frames()[0]
# print('boxscoreplayertrackv2')
# display(boxscoreplayertrackv2.columns)


# from nba_api.stats.endpoints import boxscoreadvancedv2
# help(boxscoreadvancedv2)
# boxscoreadvancedv2 = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id='0022200935')
# boxscoreadvancedv2 = boxscoreadvancedv2.get_data_frames()[0]
# print('boxscoreadvancedv2')
# display(boxscoreadvancedv2.columns)


# from nba_api.stats.endpoints import boxscorefourfactorsv2
# boxscorefourfactorsv2 = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id='0022200935')
# boxscorefourfactorsv2 = boxscorefourfactorsv2.get_data_frames()[0]
# print('boxscorefourfactorsv2')
# display(boxscorefourfactorsv2.columns)


# from nba_api.stats.endpoints import boxscoremiscv2
# boxscore3 = boxscoremiscv2.BoxScoreMiscV2(game_id='0022200935')
# boxscore3 = boxscore3.get_data_frames()[0]
# print('boxscore3')
# display(boxscore3.columns)
# # display(boxscore3)

# from nba_api.stats.endpoints import boxscorescoringv2
# boxscore4 = boxscorescoringv2.BoxScoreScoringV2(game_id='0022200935')
# boxscore4 = boxscore4.get_data_frames()[0]
# print('boxscore4')
# display(boxscore4.columns)
# # display(boxscore4)

# from nba_api.stats.endpoints import boxscoresummaryv2
# boxscore5 = boxscoresummaryv2.BoxScoreSummaryV2(game_id='0022200935')
# boxscore5 = boxscore5.get_data_frames()[0]
# print('boxscore5')
# display(boxscore5.columns)
# # display(boxscore5)

# from nba_api.stats.endpoints import boxscoretraditionalv2
# boxscore6 = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id='0022200935')
# boxscore6 = boxscore6.get_data_frames()[0]
# print('boxscore6')
# display(boxscore6.columns)
# # display(boxscore6)

# from nba_api.stats.endpoints import boxscoreusagev2
# boxscore7 = boxscoreusagev2.BoxScoreUsageV2(game_id='0022200935')
# boxscore7 = boxscore7.get_data_frames()[0]
# print('boxscore7')
# display(boxscore7.columns)
# # display(boxscore7)
